# %% [markdown]
# <a href="https://colab.research.google.com/github/muribe12/Breting/blob/master/api_call.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

api_key = '613790d7209ca'

address = 'https://www.encuentra24.com/api.php/v1/crm/index?slug=melania-uribe&adid=20443842'


headers = {'x-api-key': api_key}

response = requests.get(address, headers = headers)

print(response.status_code)
#response.raise_for_status()

results = response.json()
print(json.dumps(results))
# Out:
# 200
# []

# %%
import requests
import json

api_key = '613790d7209ca'

address = 'https://www.encuentra24.com/api.php/v1/crm/index?slug=costa-rica'

headers = {'x-api-key': api_key}

response = requests.get(address, headers = headers)

print(response.status_code)
#response.raise_for_status()

results = response.json()
print(json.dumps(results))
# Out:
# 401
# {"status": "error", "errors": {"slug": "This apikey is invalid"}}

# %%
import requests
import json

api_key = '613790d7209ca'

address = 'https://www.encuentra24.com/api.php/v1/crm/index?slug=costa-rica'

#headers = {'x-api-key': api_key}

response = requests.get(address)

print(response.status_code)
#response.raise_for_status()

results = response.json()
print(json.dumps(results))
# Out:
# 400
# {"status": "error", "errors": {"apikey": "Obligatorio"}}

# %%
pip install Flask

#mkdir /tmp/parsehub; cd /tmp/parsehub
# Out:
#   File "<ipython-input-5-d6034ed19130>", line 1
#     pip install Flask
#               ^
# SyntaxError: invalid syntax

# %%
mkdir /tmp/parsehub; cd /tmp/parsehub

# %%
# real_state.py

from flask import Flask, render_template
import requests
import json

app = Flask(__name__, template_folder='.')

@app.route('/')
def homepage():
  params = {
    'api_key': 'tb1JsguYa0uO',
  }
  r = requests.get(
      'https://www.parsehub.com/api/v2/projects/t1cGOw7VDAOh/last_ready_run/data',
      params=params)
  return render_template('main_template.html', movies=json.loads(r.text)['main_template'])

if __name__ == '__main__':
  app.run(host='0.0.0.0', debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from flask import Flask, render_template
import requests
import json

app = Flask(__name__, template_folder='.')

params = {'api_key': 'tb1JsguYa0uO',}

r = requests.get(
      'https://www.parsehub.com/api/v2/projects/t1cGOw7VDAOh/last_ready_run/data',
      params=params)

print(r.status_code)

results = r.json()

print(json.dumps(results))
# Out:
# 200
# ...

# %% [markdown]
# # New section
